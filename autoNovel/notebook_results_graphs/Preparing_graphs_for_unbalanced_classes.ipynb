# %% [markdown]
# # Import the data

# %% [markdown]
# ## List of imports

# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Gather the data

# %%
api = wandb.Api()# used to import weight and bias pipeline

# %%
runs_loss = api.runs("mhaggag96/trends_project",{"tags":"autonovel_unbalanced"})# this returned all the runs that has the tag loss experiment

# %%
runs_loss[0], runs_loss[1], runs_loss[2]
# Out:
# (<Run mhaggag96/trends_project/my279rcp (finished)>,
#  <Run mhaggag96/trends_project/b9j568h7 (finished)>,
#  <Run mhaggag96/trends_project/23ihb9aa (finished)>)

# %%
runs_loss[0]
# Out:
# <Run mhaggag96/trends_project/my279rcp (finished)>

# %%
run_names=['10%_unlabeled','10%_labeled','baseline']# it returns the runs from the news to the oldest. I had weight and bias in another tab to make sure that we are folllowing this order
data_df = []
for run in runs_loss:
  data_df.append(run.history())
test_dict = dict(zip(run_names, data_df))

# %%
data_df
# Out:
# [     ari_Head_2  ari_Head_1  cluster_acc_Head_1  _step  Cross_entropy_loss  \
#  0      0.333822    0.812966              0.9204      0            0.165102
#  1      0.337507    0.852330              0.9378      1            0.138799
#  2      0.450643    0.848768              0.9362      2            0.121157
#  3      0.518153    0.850139              0.9368      3            0.114851
#  4      0.496753    0.855416              0.9392      4            0.102629
#  ..          ...         ...                 ...    ...                 ...
#  195    0.504212    0.891636              0.9550    195            0.002331
#  196    0.537350    0.893088              0.9556    196            0.002041
#  197    0.563468    0.895425              0.9566    197            0.002488
#  198    0.528276    0.888914              0.9538    198            0.002236
#  199    0.509821    0.893016              0.9556    199            0.001574
#
#       nmi_Head_2     _runtime    lr  epoch  nmi_Head_1  Consistency_loss_total  \
#  0      0.414157    55.347285  0.10      0    0.785697                0.012729
#  1      0.400782    87.364033  0.10      1    0.819172                0.014832
#  2      0.478808   119.490366  0.10      2    0.815430                0.014773
#  3      0.546069   151.331799  0.10      3    0.816664                0.013981
#  4      0.527687   183.205233  0.10      4    0.820817                0.013853
#  ..          ...          ...   ...    ...         ...                     ...
#  195    0.613065  6360.997796  0.01    195    0.860770                0.002196
#  196    0.621315  6393.392948  0.01    196    0.862168                0.002172
#  197    0.643479  6425.658441  0.01    197    0.864406                0.002332
#  198    0.620809  6457.952298  0.01    198    0.858067                0.002051
#  199    0.620416  6491.195237  0.01    199    0.860990                0.002072
#
#       testing_acc_Head_1  Total_average_loss  Binary_cross_entropy_loss  \
#  0                 92.04            0.495667                   0.330137
#  1                 93.78            0.453636                   0.314229
#  2                 93.62            0.427691                   0.305798
#  3                 93.68            0.424883                   0.309190
#  4                 93.92            0.407021                   0.303386
#  ..                  ...                 ...                        ...
#  195               95.50            0.241812                   0.228499
#  196               95.56            0.245697                   0.232797
#  197               95.66            0.243677                   0.229532
#  198               95.38            0.232479                   0.219987
#  199               95.56            0.231348                   0.219415
#
#       cluster_acc_Head_2  Consistency_loss_part_a  Consistency_loss_part_b  \
#  0                0.5208                 0.010253                 0.002476
#  1                0.5580                 0.009225                 0.005607
#  2                0.7276                 0.009180                 0.005594
#  3                0.7572                 0.009048                 0.004934
#  4                0.7468                 0.009313                 0.004540
#  ..                  ...                      ...                      ...
#  195              0.7100                 0.000609                 0.001587
#  196              0.7192                 0.000577                 0.001594
#  197              0.7372                 0.000680                 0.001652
#  198              0.7232                 0.000605                 0.001446
#  199              0.7420                 0.000507                 0.001565
#
#         _timestamp  Head_1_training_accuracy
#  0    1.671484e+09                 93.991104
#  1    1.671484e+09                 94.881812
#  2    1.671484e+09                 95.712433
#  3    1.671484e+09                 95.858710
#  4    1.671484e+09                 96.278115
#  ..            ...                       ...
#  195  1.671490e+09                 99.944450
#  196  1.671490e+09                 99.972164
#  197  1.671490e+09                 99.952144
#  198  1.671490e+09                 99.943884
#  199  1.671490e+09                 99.987710
#
#  [200 rows x 19 columns],
#       ari_Head_2  ari_Head_1  cluster_acc_Head_1  _step  Cross_entropy_loss  \
#  0      0.342222    0.635300              0.8386      0            0.590685
#  1      0.388347    0.712467              0.8728      1            0.387312
#  2      0.400477    0.716958              0.8736      2            0.335336
#  3      0.403938    0.704638              0.8694      3            0.280800
#  4      0.386468    0.720966              0.8764      4            0.275913
#  ..          ...         ...                 ...    ...                 ...
#  195    0.689174    0.757212              0.8944    195            0.005618
#  196    0.686280    0.762610              0.8968    196            0.004877
#  197    0.687594    0.750387              0.8912    197            0.006680
#  198    0.691958    0.757225              0.8944    198            0.004966
#  199    0.693621    0.766745              0.8988    199            0.004592
#
#       nmi_Head_2     _runtime    lr  epoch  nmi_Head_1  Consistency_loss_total  \
#  0      0.414409    48.450958  0.10      0    0.640417                0.018850
#  1      0.439279    87.621154  0.10      1    0.687145                0.023765
#  2      0.454761   126.915144  0.10      2    0.696440                0.025112
#  3      0.457259   166.175654  0.10      3    0.698059                0.027025
#  4      0.436580   205.223087  0.10      4    0.703036                0.028362
#  ..          ...          ...   ...    ...         ...                     ...
#  195    0.760061  7807.731747  0.01    195    0.740963                0.003834
#  196    0.762096  7847.568569  0.01    196    0.742605                0.003888
#  197    0.762342  7888.738015  0.01    197    0.741251                0.003817
#  198    0.761195  7928.512047  0.01    198    0.744970                0.003672
#  199    0.767027  7968.341527  0.01    199    0.749270                0.003724
#
#       testing_acc_Head_1  Total_average_loss  Binary_cross_entropy_loss  \
#  0                 83.86            0.838033                   0.246714
#  1                 87.28            0.632050                   0.243762
#  2                 87.36            0.577595                   0.241007
#  3                 86.94            0.522889                   0.240459
#  4                 87.64            0.517581                   0.239608
#  ..                  ...                 ...                        ...
#  195               89.44            0.260945                   0.236157
#  196               89.68            0.260314                   0.235998
#  197               89.12            0.262018                   0.236253
#  198               89.44            0.259416                   0.236092
#  199               89.88            0.259248                   0.236037
#
#       cluster_acc_Head_2  Consistency_loss_part_a  Consistency_loss_part_b  \
#  0               0.61268                 0.018409                 0.000441
#  1               0.65780                 0.020441                 0.003324
#  2               0.64708                 0.021812                 0.003300
#  3               0.67172                 0.024059                 0.002966
#  4               0.65580                 0.025063                 0.003299
#  ..                  ...                      ...                      ...
#  195             0.76044                 0.003625                 0.000209
#  196             0.75848                 0.003678                 0.000210
#  197             0.75912                 0.003608                 0.000209
#  198             0.76256                 0.003464                 0.000207
#  199             0.76220                 0.003513                 0.000211
#
#         _timestamp  Head_1_training_accuracy
#  0    1.671460e+09                 79.641247
#  1    1.671460e+09                 87.198060
#  2    1.671460e+09                 87.459702
#  3    1.671460e+09                 90.256744
#  4    1.671460e+09                 89.968447
#  ..            ...                       ...
#  195  1.671468e+09                 99.974141
#  196  1.671468e+09                 99.972620
#  197  1.671468e+09                 99.948283
#  198  1.671468e+09                100.000000
#  199  1.671468e+09                100.000000
#
#  [200 rows x 19 columns],
#       ari_Head_2  ari_Head_1  cluster_acc_Head_1  _step  Cross_entropy_loss  \
#  0      0.387544    0.822444              0.9244      0            0.231280
#  1      0.421906    0.816757              0.9228      1            0.163454
#  2      0.466028    0.858435              0.9406      2            0.151774
#  3      0.445386    0.842248              0.9336      3            0.134162
#  4      0.428725    0.860669              0.9416      4            0.121800
#  ..          ...         ...                 ...    ...                 ...
#  195    0.782604    0.889039              0.9538    195            0.003287
#  196    0.776735    0.885236              0.9522    196            0.002980
#  197    0.776292    0.888527              0.9536    197            0.003296
#  198    0.773281    0.891962              0.9550    198            0.003016
#  199    0.773924    0.891407              0.9548    199            0.002576
#
#       nmi_Head_2  _runtime    lr  epoch  nmi_Head_1  Consistency_loss_total  \
#  0      0.440771        39  0.10      0    0.787837                0.021282
#  1      0.466251        73  0.10      1    0.789758                0.022237
#  2      0.501360       108  0.10      2    0.826708                0.023130
#  3      0.479131       143  0.10      3    0.811347                0.023101
#  4      0.472512       177  0.10      4    0.828128                0.022413
#  ..          ...       ...   ...    ...         ...                     ...
#  195    0.787636      6747  0.01    195    0.859108                0.002160
#  196    0.784058      6781  0.01    196    0.853741                0.002150
#  197    0.783766      6815  0.01    197    0.857330                0.002217
#  198    0.781001      6849  0.01    198    0.862003                0.002301
#  199    0.782842      6883  0.01    199    0.861196                0.002251
#
#       testing_acc_Head_2  testing_acc_Head_1  Total_average_loss  \
#  0                 6.644               92.44            0.479486
#  1                 5.612               92.28            0.410897
#  2                 3.508               94.06            0.398443
#  3                 3.444               93.36            0.380886
#  4                 2.568               94.16            0.368764
#  ..                  ...                 ...                 ...
#  195               1.312               95.38            0.255467
#  196               1.320               95.22            0.255148
#  197               1.072               95.36            0.250551
#  198               1.288               95.50            0.252824
#  199               1.120               95.48            0.252303
#
#       Binary_cross_entropy_loss  cluster_acc_Head_2  Consistency_loss_part_a  \
#  0                     0.247489             0.64152                 0.019422
#  1                     0.246530             0.70448                 0.019489
#  2                     0.245516             0.72864                 0.019695
#  3                     0.245331             0.71048                 0.019528
#  4                     0.245337             0.69636                 0.018762
#  ..                         ...                 ...                      ...
#  195                   0.241379             0.90380                 0.001722
#  196                   0.241416             0.90092                 0.001689
#  197                   0.236170             0.90024                 0.001669
#  198                   0.238303             0.89928                 0.001687
#  199                   0.238473             0.89920                 0.001659
#
#       Consistency_loss_part_b  _timestamp  Head_1_training_accuracy
#  0                   0.001861  1669296122                 91.989382
#  1                   0.002748  1669296156                 94.148135
#  2                   0.003434  1669296191                 94.557570
#  3                   0.003573  1669296226                 95.321285
#  4                   0.003651  1669296260                 95.595392
#  ..                       ...         ...                       ...
#  195                 0.000438  1669302830                 99.968638
#  196                 0.000461  1669302864                 99.976595
#  197                 0.000548  1669302898                 99.937047
#  198                 0.000614  1669302932                 99.967129
#  199                 0.000592  1669302966                 99.976903
#
#  [200 rows x 20 columns]]

# %%
test_dict.keys()
# Out:
# dict_keys(['10%_unlabeled', '10%_labeled', 'baseline'])

# %%
test_dict['10%_unlabeled']
# Out:
#      ari_Head_2  ari_Head_1  cluster_acc_Head_1  _step  Cross_entropy_loss  \
# 0      0.333822    0.812966              0.9204      0            0.165102
# 1      0.337507    0.852330              0.9378      1            0.138799
# 2      0.450643    0.848768              0.9362      2            0.121157
# 3      0.518153    0.850139              0.9368      3            0.114851
# 4      0.496753    0.855416              0.9392      4            0.102629
# ..          ...         ...                 ...    ...                 ...
# 195    0.504212    0.891636              0.9550    195            0.002331
# 196    0.537350    0.893088              0.9556    196            0.002041
# 197    0.563468    0.895425              0.9566    197            0.002488
# 198    0.528276    0.888914              0.9538    198            0.002236
# 199    0.509821    0.893016              0.9556    199            0.001574
#
#      nmi_Head_2     _runtime    lr  epoch  nmi_Head_1  Consistency_loss_total  \
# 0      0.414157    55.347285  0.10      0    0.785697                0.012729
# 1      0.400782    87.364033  0.10      1    0.819172                0.014832
# 2      0.478808   119.490366  0.10      2    0.815430                0.014773
# 3      0.546069   151.331799  0.10      3    0.816664                0.013981
# 4      0.527687   183.205233  0.10      4    0.820817                0.013853
# ..          ...          ...   ...    ...         ...                     ...
# 195    0.613065  6360.997796  0.01    195    0.860770                0.002196
# 196    0.621315  6393.392948  0.01    196    0.862168                0.002172
# 197    0.643479  6425.658441  0.01    197    0.864406                0.002332
# 198    0.620809  6457.952298  0.01    198    0.858067                0.002051
# 199    0.620416  6491.195237  0.01    199    0.860990                0.002072
#
#      testing_acc_Head_1  Total_average_loss  Binary_cross_entropy_loss  \
# 0                 92.04            0.495667                   0.330137
# 1                 93.78            0.453636                   0.314229
# 2                 93.62            0.427691                   0.305798
# 3                 93.68            0.424883                   0.309190
# 4                 93.92            0.407021                   0.303386
# ..                  ...                 ...                        ...
# 195               95.50            0.241812                   0.228499
# 196               95.56            0.245697                   0.232797
# 197               95.66            0.243677                   0.229532
# 198               95.38            0.232479                   0.219987
# 199               95.56            0.231348                   0.219415
#
#      cluster_acc_Head_2  Consistency_loss_part_a  Consistency_loss_part_b  \
# 0                0.5208                 0.010253                 0.002476
# 1                0.5580                 0.009225                 0.005607
# 2                0.7276                 0.009180                 0.005594
# 3                0.7572                 0.009048                 0.004934
# 4                0.7468                 0.009313                 0.004540
# ..                  ...                      ...                      ...
# 195              0.7100                 0.000609                 0.001587
# 196              0.7192                 0.000577                 0.001594
# 197              0.7372                 0.000680                 0.001652
# 198              0.7232                 0.000605                 0.001446
# 199              0.7420                 0.000507                 0.001565
#
#        _timestamp  Head_1_training_accuracy
# 0    1.671484e+09                 93.991104
# 1    1.671484e+09                 94.881812
# 2    1.671484e+09                 95.712433
# 3    1.671484e+09                 95.858710
# 4    1.671484e+09                 96.278115
# ..            ...                       ...
# 195  1.671490e+09                 99.944450
# 196  1.671490e+09                 99.972164
# 197  1.671490e+09                 99.952144
# 198  1.671490e+09                 99.943884
# 199  1.671490e+09                 99.987710
#
# [200 rows x 19 columns]

# %% [markdown]
# # Plot the data

# %% [markdown]
# ## Head1 metrics

# %%
# NMI
fig, ax= plt.subplots(figsize=(20, 15), facecolor='white');
ax.plot(test_dict['10%_unlabeled'].nmi_Head_1.tolist(), color='orange',label="10% unlabeled") ;
ax.plot(test_dict['10%_labeled'].nmi_Head_1.tolist(), color='blue',label="10% labeled") ;
ax.plot(test_dict['baseline'].nmi_Head_1.tolist(), color='purple',label="baseline") ;
ax.set_xlabel('Epochs',fontsize=20);
ax.set_ylabel('NMI',fontsize=20);
ax.set_title('Head1 - Clustering Metric #1',fontsize=25);
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best', framealpha=0.8,fontsize=17)
plt.show()

# %%
# CLUSTER ACC
fig, ax= plt.subplots(figsize=(20, 15), facecolor='white');
ax.plot(test_dict['10%_unlabeled'].cluster_acc_Head_1.tolist(), color='orange',label="10% unlabeled") ;
ax.plot(test_dict['10%_labeled'].cluster_acc_Head_1.tolist(), color='blue',label="10% labeled") ;
ax.plot(test_dict['baseline'].cluster_acc_Head_1.tolist(), color='purple',label="baseline") ;
ax.set_xlabel('Epochs',fontsize=20);
ax.set_ylabel('Clustering Accuracy',fontsize=20);
ax.set_title('Head1 - Clustering Metric #2',fontsize=25);
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best', framealpha=0.8,fontsize=17)
plt.show()

# %%
# ARI
fig, ax= plt.subplots(figsize=(20, 15), facecolor='white');
ax.plot(test_dict['10%_unlabeled'].ari_Head_1.tolist(), color='orange',label="10% unlabeled") ;
ax.plot(test_dict['10%_labeled'].ari_Head_1.tolist(), color='blue',label="10% labeled") ;
ax.plot(test_dict['baseline'].ari_Head_1.tolist(), color='purple',label="baseline") ;
ax.set_xlabel('Epochs',fontsize=20);
ax.set_ylabel('ARI',fontsize=20);
ax.set_title('Head1 - Clustering Metric #3',fontsize=25);
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best', framealpha=0.8,fontsize=17)
plt.show()

# %%
# TESTING ACC ACC
fig, ax= plt.subplots(figsize=(20, 15), facecolor='white');
ax.plot(test_dict['10%_unlabeled'].testing_acc_Head_1.tolist(), color='orange',label="10% unlabeled") ;
ax.plot(test_dict['10%_labeled'].testing_acc_Head_1.tolist(), color='blue',label="10% labeled") ;
ax.plot(test_dict['baseline'].testing_acc_Head_1.tolist(), color='purple',label="baseline") ;
ax.set_xlabel('Epochs',fontsize=20);
ax.set_ylabel('Testing Accuracy',fontsize=20);
ax.set_title('Head1 - Accuracy Metric #1',fontsize=25);
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best', framealpha=0.8,fontsize=17)
plt.show()

# %% [markdown]
# ## Head2 metrics

# %%
# NMI
fig, ax= plt.subplots(figsize=(20, 15), facecolor='white');
ax.plot(test_dict['10%_unlabeled'].nmi_Head_2.tolist(), color='orange',label="10% unlabeled") ;
ax.plot(test_dict['10%_labeled'].nmi_Head_2.tolist(), color='blue',label="10% labeled") ;
ax.plot(test_dict['baseline'].nmi_Head_2.tolist(), color='purple',label="baseline") ;
ax.set_xlabel('Epochs',fontsize=20);
ax.set_ylabel('NMI',fontsize=20);
ax.set_title('Head2 - Clustering Metric #1',fontsize=25);
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best', framealpha=0.8,fontsize=17)
plt.show()

# %%
# CLUSTER ACC
fig, ax= plt.subplots(figsize=(20, 15), facecolor='white');
ax.plot(test_dict['10%_unlabeled'].cluster_acc_Head_2.tolist(), color='orange',label="10% unlabeled") ;
ax.plot(test_dict['10%_labeled'].cluster_acc_Head_2.tolist(), color='blue',label="10% labeled") ;
ax.plot(test_dict['baseline'].cluster_acc_Head_2.tolist(), color='purple',label="baseline") ;
ax.set_xlabel('Epochs',fontsize=20);
ax.set_ylabel('Clustering Accuracy',fontsize=20);
ax.set_title('Head2 - Clustering Metric #2',fontsize=25);
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best', framealpha=0.8,fontsize=17)
plt.show()

# %%
# ARI
fig, ax= plt.subplots(figsize=(20, 15), facecolor='white');
ax.plot(test_dict['10%_unlabeled'].ari_Head_2.tolist(), color='orange',label="10% unlabeled") ;
ax.plot(test_dict['10%_labeled'].ari_Head_2.tolist(), color='blue',label="10% labeled") ;
ax.plot(test_dict['baseline'].ari_Head_2.tolist(), color='purple',label="baseline") ;
ax.set_xlabel('Epochs',fontsize=20);
ax.set_ylabel('ARI',fontsize=20);
ax.set_title('Head2 - Clustering Metric #3',fontsize=25);
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='best', framealpha=0.8,fontsize=17)
plt.show()
